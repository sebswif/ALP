# %% [markdown]
# # 720 magnetic field lines ? spacecraft removed
# The two generated images are saved directly below. No execution is required.

# %%
# Saved plots: 720 magnetic field lines, no spacecraft or orbit.
from pathlib import Path
from IPython.display import Image, display
here = Path.cwd().resolve()
output = next((b / s for b in [here, *here.parents] for s in [Path("outputs/DarkNESSpov_bfield"), Path("ALP/outputs/DarkNESSpov_bfield")] if (b / s / "field_lines_3d.png").is_file()), None)
if output is None:
    raise FileNotFoundError("Open this notebook within the project")
for name in ["field_lines_3d.png", "earth_3d.png"]:
    display(Image(filename=str(output / name)))
# Out:
# field_lines_3d.png ? 720 field lines; no spacecraft
# earth_3d.png ? 720 field lines; no spacecraft
